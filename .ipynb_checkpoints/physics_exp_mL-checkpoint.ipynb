# %% [markdown]
# ## Problem Statement
# `In the field of particle physics, accurate identification and classification of events are crucial for understanding fundamental particles and their interactions. The provided dataset contains various features derived from particle physics experiments, and the goal is to build a machine-learning model to classify events into signal (s) and background (b) categories. This classification aids in distinguishing events of interest (signal) from background noise.`

# %% [markdown]
# ### Objective:
# `The primary goal of this machine learning project is to
# develop a model that can accurately predict whether a
# given set of experimental features corresponds to a signal
# or background event. Successful classification contributes
# to the advancement of particle physics research by
# automating the identification of events that may indicate
# the presence of specific particles or phenomena.`

# %% [markdown]
# ### Data Description
# `EventId`: Identifier for each event in the experiment.
#
# `DER_mass_MMC`: Derived mass of the Missing Mass Calculator. Represents the calculated mass of a system using the missing energy in the experiment.
#
# `DER_mass_transverse_met_lep`: Indicates the mass calculated from the transverse components of missing energy and lepton.
#
# `DER_mass_vis`: Derived mass of the visible part of the system. Represents the mass of the visible particles in the system, excluding invisible or undetected particles.
#
# `DER_pt_h`: Transverse momentum of the Higgs boson. Indicates the momentum of the Higgs boson in the transverse plane, providing information about its motion.
#
# `DER_deltaeta_jet_jet`: The absolute difference in pseudorapidity between the two jets. Describes the angular separation between two jets in the experiment.
#
# `DER_mass_jet_jet`: Derived mass of the two jets.
#
# `DER_lep_eta_centrality`: Pseudorapidity centrality of the lepton concerning jets. Pseudorapidity is a spatial coordinate used in particle physics. This feature likely indicates the centrality of the lepton (a charged particle, possibly an electron or a muon) concerning jets in the event. The centrality provides information about the lepton's position relative to the jets.
#
# `PRI_tau_pt`: Transverse momentum of the tau. Transverse momentum is the momentum of a particle in the direction perpendicular to the beamline. This feature represents the transverse momentum of the tau particle, which is a heavy, charged particle often involved in processes like tau decays.
#
# `PRI_tau_eta`: Pseudorapidity of the tau. Pseudorapidity is a measure of the angle of a particle's trajectory relative to the beamline. This feature indicates the pseudorapidity of the tau particle, providing information about its direction.
#
# `PRI_tau_phi`: Azimuthal angle of the tau. Azimuthal angle defines the rotation of a particle's trajectory around the beamline. This feature represents the azimuthal angle of the tau particle, indicating its orientation in the transverse plane.
#
# `PRI_lep_pt`: Transverse momentum of the lepton. Similar to PRI_tau_pt, this feature represents the transverse momentum of the lepton (electron or muon) in the event.
#
# `PRI_lep_eta`: Pseudorapidity of the lepton. Similar to PRI_tau_eta, this feature indicates the pseudorapidity of the lepton, providing information about its angular position relative to the beamline.
#
# `PRI_lep_phi`: Azimuthal angle of the lepton. Similar to PRI_tau_phi, this feature represents the azimuthal angle of the lepton, indicating its orientation in the transverse plane.
#
# `PRI_met`: Missing transverse energy. Missing transverse energy is a crucial concept in particle physics. It represents the imbalance in transverse energy in an event, suggesting the presence of undetected particles or neutrinos.
#
# `PRI_met_phi`: Azimuthal angle of the missing transverse energy. Similar to PRI_tau_phi and PRI_lep_phi, this feature represents the azimuthal angle of the missing transverse energy, indicating its orientation in the transverse plane.
#
# `PRI_met_sumet`: Sum of the transverse energy of all objects in the event. This feature represents the sum of the transverse energy (energy component perpendicular to the beamline) of all objects (particles) detected in the event. It provides a measure of the overall energy flow in the transverse plane.
#
# `PRI_jet_num`: Number of jets in the event. Indicates the count of jets observed in the event. Jets are collimated sprays of particles resulting from highenergy interactions. Knowing the number of jets is crucial for understanding the event's characteristics.
#
# `PRI_jet_leading_pt`: Transverse momentum of the leading jet. Represents the transverse momentum of the jet with the highest transverse momentum in the event. The leading jet is the one with the most significant momentum contribution.
#
# `PRI_jet_leading_eta`: Pseudorapidity of the leading jet. Indicates the pseudorapidity (angular position) of the leading jet, providing information about its direction in the detector.
#
# `PRI_jet_leading_phi`: Azimuthal angle of the leading jet. Represents the azimuthal angle of the leading jet, indicating its orientation in the transverse plane.
#
# `PRI_jet_subleading_pt`: Transverse momentum of the subleading jet. Represents the transverse momentum of the second-highest transverse momentum jet in the event (subleading jet).
#
# `PRI_jet_subleading_eta`: Pseudorapidity of the subleading jet. Indicates the pseudorapidity of the subleading jet, providing information about its angular position in the detector.
#
# `PRI_jet_subleading_phi`: Azimuthal angle of the subleading jet. Represents the azimuthal angle of the subleading jet, indicating its orientation in the transverse plane.
#
# `PRI_jet_all_pt`: Sum of the transverse momentum of all jets in the event. This feature represents the sum of the transverse momentum of all jets detected in the event. It provides a measure of the overall transverse momentum contributed by all jets.
#
# `Weight`: A weight associated with each event. The weight is a numerical value assigned to each event. It is often used as a scaling factor to account for the significance or importance of each event in the analysis. The weight may be applied during training and evaluation to adjust the contribution of each event to the model.
#
# `Target column(Label)`: The target variable, indicating the class or label of each event (s or b). This is
# the target variable where each event is labeled as either signal (s) or background (b).

# %%
from IPython.display import Image
# Image(filename='der.jpeg')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# url = 'https://raw.githubusercontent.com/sudhirjangra/physics_exp_machine_learning/main/data_science_dataset.csv'
df = pd.read_csv('data_science_dataset.csv')
# df = pd.read_csv(url)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   EventId                      250000 non-null  int64
#  1   DER_mass_MMC                 250000 non-null  float64
#  2   DER_mass_transverse_met_lep  250000 non-null  float64
#  3   DER_mass_vis                 250000 non-null  float64
#  4   DER_pt_h                     250000 non-null  float64
#  5   DER_deltaeta_jet_jet         250000 non-null  float64
#  6   DER_mass_jet_jet             250000 non-null  float64
#  7   DER_prodeta_jet_jet          250000 non-null  float64
#  8   DER_deltar_tau_lep           250000 non-null  float64
#  9   DER_pt_tot                   250000 non-null  float64
#  10  DER_sum_pt                   250000 non-null  float64
#  11  DER_pt_ratio_lep_tau         250000 non-null  float64
#  12  DER_met_phi_centrality       250000 non-null  float64
#  13  DER_lep_eta_centrality       250000 non-null  float64
#  14  PRI_tau_pt                   250000 non-null  float64
#  15  PRI_tau_eta                  250000 non-null  float64
#  16  PRI_tau_phi                  250000 non-null  float64
#  17  PRI_lep_pt                   250000 non-null  float64
#  18  PRI_lep_eta                  250000 non-null  float64
#  19  PRI_lep_phi                  250000 non-null  float64
#  20  PRI_met                      250000 non-null  float64
#  21  PRI_met_phi                  250000 non-null  float64
#  22  PRI_met_sumet                250000 non-null  float64
#  23  PRI_jet_num                  250000 non-null  int64
#  24  PRI_jet_leading_pt           250000 non-null  float64
#  25  PRI_jet_leading_eta          250000 non-null  float64
#  26  PRI_jet_leading_phi          250000 non-null  float64
#  27  PRI_jet_subleading_pt        250000 non-null  float64
#  28  PRI_jet_subleading_eta       250000 non-null  float64
#  29  PRI_jet_subleading_phi       250000 non-null  float64
#  30  PRI_jet_all_pt               250000 non-null  float64
#  31  Weight                       250000 non-null  float64
#  32  Label                        250000 non-null  object
# dtypes: float64(30), int64(2), object(1)
# memory usage: 62.9+ MB

# %%
df.sample(8)
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 201250   301250        95.812                       57.304        71.510
# 10222    110222      -999.000                       95.252        81.311
# 17259    117259       105.327                        5.087        65.516
# 48248    148248       140.200                       66.511        91.710
# 121663   221663       108.853                       31.511        62.758
# 189594   289594        81.112                       36.414        52.340
# 187988   287988       112.390                       82.376        79.632
# 183597   283597       127.689                        9.054        91.213
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 201250    56.322              -999.000          -999.000             -999.000
# 10222     37.965              -999.000          -999.000             -999.000
# 17259     84.631              -999.000          -999.000             -999.000
# 48248      1.787              -999.000          -999.000             -999.000
# 121663    95.793                 0.744            37.820               -0.085
# 189594   174.775                 0.632            54.582                0.584
# 187988    24.047              -999.000          -999.000             -999.000
# 183597   145.019              -999.000          -999.000             -999.000
#
#         DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# 201250               2.090      18.723     154.195                 1.685
# 10222                2.198       2.223     117.092                 0.914
# 17259                1.774      21.803     150.458                 0.638
# 48248                3.042       1.787      88.667                 1.608
# 121663               2.098      22.220     155.617                 1.667
# 189594               0.943      47.422     312.456                 0.415
# 187988               2.964      24.047      70.042                 2.020
# 183597               1.440      21.098     269.859                 1.138
#
#         DER_met_phi_centrality  DER_lep_eta_centrality  PRI_tau_pt  \
# 201250                  -1.114                -999.000      30.954
# 10222                   -1.228                -999.000      40.532
# 17259                    1.136                -999.000      51.045
# 48248                   -1.369                -999.000      34.001
# 121663                   1.407                   0.009      24.006
# 189594                   1.106                   0.000      88.504
# 187988                   0.331                -999.000      23.189
# 183597                   1.152                -999.000      64.345
#
#         PRI_tau_eta  PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  \
# 201250        1.394       -2.449      52.165        0.853       -0.431
# 10222        -0.298       -2.070      37.038        1.032        2.463
# 17259         0.082        1.515      32.589        0.702       -3.107
# 48248        -1.719       -0.631      54.666       -2.450        2.699
# 121663       -2.338       -0.321      40.024       -1.036       -1.966
# 189594       -1.785       -1.536      36.737       -2.127       -2.415
# 187988       -0.481       -2.863      46.852        0.857        0.776
# 183597       -1.410        2.714      73.202       -1.706       -2.161
#
#         PRI_met  PRI_met_phi  PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  \
# 201250   46.650        0.809        259.772            1              71.076
# 10222    62.415       -0.403        140.554            1              39.522
# 17259    35.774        3.027        183.491            1              66.825
# 48248    20.568       -0.186         76.780            0            -999.000
# 121663   50.962       -1.253        273.206            2              53.032
# 189594   59.854       -1.617        429.110            3              98.773
# 187988   37.090       -2.676        174.228            0            -999.000
# 183597   43.725       -2.321        284.066            1             132.312
#
#         PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# 201250               -0.431                2.820               -999.000
# 10222                -1.558                1.774               -999.000
# 17259                -1.913               -0.858               -999.000
# 48248              -999.000             -999.000               -999.000
# 121663               -0.602                1.584                 38.554
# 189594                0.511                1.671                 54.634
# 187988             -999.000             -999.000               -999.000
# 183597                1.198                0.352               -999.000
#
#         PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt  \
# 201250                -999.000                -999.000          71.076
# 10222                 -999.000                -999.000          39.522
# 17259                 -999.000                -999.000          66.825
# 48248                 -999.000                -999.000           0.000
# 121663                   0.141                   1.582          91.586
# 189594                   1.143                   1.679         187.214
# 187988                -999.000                -999.000           0.000
# 183597                -999.000                -999.000         132.312
#
#           Weight Label
# 201250  1.373391     b
# 10222   2.066393     b
# 17259   0.018636     s
# 48248   4.823982     b
# 121663  0.744056     b
# 189594  0.788778     b
# 187988  5.513647     b
# 183597  0.928743     b

# %%
df.index = df['EventId']
df.drop(columns='EventId', inplace=True)

# %%
df.shape
# Out:
# (250000, 32)

# %%
df = df.replace(-999, 0)
# to handle missing values

# %%
print(df.isna().mean()*100)
# df.dropna(inplace=True)
# Out:
# DER_mass_MMC                   0.0
# DER_mass_transverse_met_lep    0.0
# DER_mass_vis                   0.0
# DER_pt_h                       0.0
# DER_deltaeta_jet_jet           0.0
# DER_mass_jet_jet               0.0
# DER_prodeta_jet_jet            0.0
# DER_deltar_tau_lep             0.0
# DER_pt_tot                     0.0
# DER_sum_pt                     0.0
# DER_pt_ratio_lep_tau           0.0
# DER_met_phi_centrality         0.0
# DER_lep_eta_centrality         0.0
# PRI_tau_pt                     0.0
# PRI_tau_eta                    0.0
# PRI_tau_phi                    0.0
# PRI_lep_pt                     0.0
# PRI_lep_eta                    0.0
# PRI_lep_phi                    0.0
# PRI_met                        0.0
# PRI_met_phi                    0.0
# PRI_met_sumet                  0.0
# PRI_jet_num                    0.0
# PRI_jet_leading_pt             0.0
# PRI_jet_leading_eta            0.0
# PRI_jet_leading_phi            0.0
# PRI_jet_subleading_pt          0.0
# PRI_jet_subleading_eta         0.0
# PRI_jet_subleading_phi         0.0
# PRI_jet_all_pt                 0.0
# Weight                         0.0
# Label                          0.0
# dtype: float64

# %%
df.sample(6)
# Out:
#          DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# EventId
# 337353         90.887                        4.068        64.621   201.770
# 269795        145.892                       13.058        99.584    38.219
# 105356         81.994                        8.767        41.346   174.331
# 331709          0.000                       91.791        26.001     5.853
# 229074        110.288                       11.346        56.961   102.273
# 291625         95.169                       73.301        71.497    46.900
#
#          DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# EventId
# 337353                  2.002           262.358               -0.974
# 269795                  0.000             0.000                0.000
# 105356                  0.000             0.000                0.000
# 331709                  0.000             0.000                0.000
# 229074                  2.913           352.859               -2.107
# 291625                  0.000             0.000                0.000
#
#          DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# EventId
# 337353                0.849       1.209     375.608                 0.978
# 269795                2.491       3.489     147.581                 0.466
# 105356                0.984      24.665     240.241                 1.060
# 331709                0.725       5.853      72.734                 0.806
# 229074                1.997       0.847     227.268                 1.081
# 291625                2.044       1.233     132.533                 1.669
#
#          DER_met_phi_centrality  DER_lep_eta_centrality  PRI_tau_pt  \
# EventId
# 337353                    1.304                   0.655      75.017
# 269795                   -0.653                   0.000      76.917
# 105356                    0.682                   0.000      39.601
# 331709                   -1.405                   0.000      40.274
# 229074                    1.206                   0.993      30.242
# 291625                    0.006                   0.000      31.929
#
#          PRI_tau_eta  PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  \
# EventId
# 337353        -0.336       -1.594      73.366        0.483       -1.817
# 269795        -0.515       -1.126      35.879       -0.568        1.364
# 105356         1.333       -1.424      41.995        0.416       -1.780
# 331709        -2.361       -2.790      32.459       -1.962       -2.185
# 229074         0.649       -0.347      32.706       -0.243        1.440
# 291625        -1.344        2.494      53.303       -1.743       -1.785
#
#          PRI_met  PRI_met_phi  PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  \
# EventId
# 337353    54.354       -1.753        411.770            2             164.204
# 269795    19.440        1.863        156.797            1              34.786
# 105356    96.132       -1.918        258.979            1             158.644
# 331709    66.053        0.690         98.299            0               0.000
# 229074    67.230        1.197        209.514            2              97.234
# 291625    27.372        1.928        168.588            1              47.301
#
#          PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# EventId
# 337353                 0.833                1.695                 63.022
# 269795                 2.265                2.701                  0.000
# 105356                 0.675                1.480                  0.000
# 331709                 0.000                0.000                  0.000
# 229074                -1.581               -1.475                 67.086
# 291625                 1.516                0.129                  0.000
#
#          PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt  \
# EventId
# 337353                   -1.169                   0.627         227.225
# 269795                    0.000                   0.000          34.786
# 105356                    0.000                   0.000         158.644
# 331709                    0.000                   0.000           0.000
# 229074                    1.332                   2.972         164.320
# 291625                    0.000                   0.000          47.301
#
#            Weight Label
# EventId
# 337353   1.454848     b
# 269795   0.018636     s
# 105356   1.681611     b
# 331709   1.854838     b
# 229074   0.001503     s
# 291625   0.001503     s

# %%
df.isnull().mean()*100
# Out:
# DER_mass_MMC                   0.0
# DER_mass_transverse_met_lep    0.0
# DER_mass_vis                   0.0
# DER_pt_h                       0.0
# DER_deltaeta_jet_jet           0.0
# DER_mass_jet_jet               0.0
# DER_prodeta_jet_jet            0.0
# DER_deltar_tau_lep             0.0
# DER_pt_tot                     0.0
# DER_sum_pt                     0.0
# DER_pt_ratio_lep_tau           0.0
# DER_met_phi_centrality         0.0
# DER_lep_eta_centrality         0.0
# PRI_tau_pt                     0.0
# PRI_tau_eta                    0.0
# PRI_tau_phi                    0.0
# PRI_lep_pt                     0.0
# PRI_lep_eta                    0.0
# PRI_lep_phi                    0.0
# PRI_met                        0.0
# PRI_met_phi                    0.0
# PRI_met_sumet                  0.0
# PRI_jet_num                    0.0
# PRI_jet_leading_pt             0.0
# PRI_jet_leading_eta            0.0
# PRI_jet_leading_phi            0.0
# PRI_jet_subleading_pt          0.0
# PRI_jet_subleading_eta         0.0
# PRI_jet_subleading_phi         0.0
# PRI_jet_all_pt                 0.0
# Weight                         0.0
# Label                          0.0
# dtype: float64

# %%
df.describe()
# Out:
#         DER_mass_MMC  DER_mass_transverse_met_lep   DER_mass_vis  \
# count  250000.000000                250000.000000  250000.000000
# mean      103.280465                    49.239819      81.181982
# std        68.566103                    35.344886      40.828691
# min         0.000000                     0.000000       6.329000
# 25%        78.100750                    19.241000      59.388750
# 50%       105.012000                    46.524000      73.752000
# 75%       130.606250                    73.598000      92.259000
# max      1192.026000                   690.075000    1349.351000
#
#             DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000         250000.000000     250000.000000
# mean       57.895962              0.697533        107.881121
# std        63.655682              1.439145        272.698950
# min         0.000000              0.000000          0.000000
# 25%        14.068750              0.000000          0.000000
# 50%        38.467500              0.000000          0.000000
# 75%        79.169000              0.490000         83.446000
# max      2834.999000              9.000000       4974.979000
#
#        DER_prodeta_jet_jet  DER_deltar_tau_lep     DER_pt_tot     DER_sum_pt  \
# count        250000.000000       250000.000000  250000.000000  250000.000000
# mean             -0.238431            2.373100      18.917332     158.432217
# std               1.966484            0.782911      22.273494     115.706115
# min             -18.066000            0.208000       0.000000      46.104000
# 25%               0.000000            1.810000       2.841000      77.550000
# 50%               0.000000            2.491500      12.315500     120.664500
# 75%               0.000000            2.961000      27.591000     200.478250
# max              16.690000            5.684000    2834.999000    1852.462000
#
#        DER_pt_ratio_lep_tau  DER_met_phi_centrality  DER_lep_eta_centrality  \
# count         250000.000000           250000.000000           250000.000000
# mean               1.437609               -0.128305                0.132983
# std                0.844743                1.193585                0.298968
# min                0.047000               -1.414000                0.000000
# 25%                0.883000               -1.371000                0.000000
# 50%                1.280000               -0.356000                0.000000
# 75%                1.777000                1.225000                0.000000
# max               19.773000                1.414000                1.000000
#
#           PRI_tau_pt    PRI_tau_eta    PRI_tau_phi     PRI_lep_pt  \
# count  250000.000000  250000.000000  250000.000000  250000.000000
# mean       38.707419      -0.010973      -0.008171      46.660207
# std        22.412081       1.214079       1.816763      22.064922
# min        20.000000      -2.499000      -3.142000      26.000000
# 25%        24.591750      -0.925000      -1.575000      32.375000
# 50%        31.804000      -0.023000      -0.033000      40.516000
# 75%        45.017000       0.898000       1.565000      53.390000
# max       764.408000       2.497000       3.142000     560.271000
#
#          PRI_lep_eta    PRI_lep_phi        PRI_met    PRI_met_phi  \
# count  250000.000000  250000.000000  250000.000000  250000.000000
# mean       -0.019507       0.043543      41.717235      -0.010119
# std         1.264982       1.816611      32.894693       1.812223
# min        -2.505000      -3.142000       0.109000      -3.142000
# 25%        -1.014000      -1.522000      21.398000      -1.575000
# 50%        -0.045000       0.086000      34.802000      -0.024000
# 75%         0.959000       1.618000      51.895000       1.561000
# max         2.503000       3.142000    2842.617000       3.142000
#
#        PRI_met_sumet    PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  250000.000000  250000.000000       250000.000000        250000.000000
# mean      209.797178       0.979176           50.922781            -0.001966
# std       126.499506       0.977426           62.733376             1.382703
# min        13.678000       0.000000            0.000000            -4.499000
# 25%       123.017500       0.000000            0.000000            -0.433000
# 50%       179.739000       1.000000           38.960000             0.000000
# 75%       263.379250       2.000000           75.349000             0.433000
# max      2003.976000       3.000000         1120.573000             4.499000
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count        250000.000000          250000.000000           250000.000000
# mean             -0.007440              16.736968               -0.003437
# std               1.405061              31.338880                1.094459
# min              -3.142000               0.000000               -4.500000
# 25%              -0.556000               0.000000                0.000000
# 50%               0.000000               0.000000                0.000000
# 75%               0.503000              33.703000                0.000000
# max               3.141000             721.456000                4.500000
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt         Weight
# count           250000.000000   250000.000000  250000.000000
# mean                -0.000459       73.064591       1.646767
# std                  0.978743       98.015662       1.875103
# min                 -3.142000        0.000000       0.001502
# 25%                  0.000000        0.000000       0.018636
# 50%                  0.000000       40.512500       1.156188
# 75%                  0.000000      109.933750       2.404128
# max                  3.142000     1633.433000       7.822543

# %%
df['Label'].value_counts()
# Out:
# Label
# b    164333
# s     85667
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Label'], data=df, hue='Label')
plt.show()

# %%
# checking distribution of our input features
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']

plt.figure(figsize=(15, 100))
for i, col in enumerate(numeric_features):
    plt.subplot(60, 3, i+1)
    sns.distplot(x=df[col], color='indianred')
    plt.xlabel(col, weight='bold')
    plt.tight_layout()

# %%
df_numeric = df[numeric_features]
corr_matrix = df_numeric.corr().abs()
threshold = 0.7
multicollinear_feature = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if corr_matrix.iloc[i,j]>=threshold:
            multicollinear_feature.add(corr_matrix.columns[i])
            multicollinear_feature.add(corr_matrix.columns[j])

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of features')
plt.show()
print('Highly correlated features: ', multicollinear_feature)
# Out:
# Highly correlated features:  {'DER_pt_ratio_lep_tau', 'PRI_jet_all_pt', 'DER_pt_h', 'DER_mass_jet_jet', 'PRI_jet_leading_pt', 'PRI_jet_num', 'DER_sum_pt', 'DER_lep_eta_centrality', 'DER_deltaeta_jet_jet', 'DER_prodeta_jet_jet', 'PRI_lep_pt', 'PRI_met_sumet', 'PRI_jet_subleading_pt'}

# %%
len(multicollinear_feature)
# Out:
# 13

# %%
# dropping highly correlated feature from the dataset (feature which are correlated >70%)
df.drop(multicollinear_feature, axis=1, inplace=True)

# %%
df.shape
# Out:
# (250000, 19)

# %%
df.sample(5)
# Out:
#          DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# EventId
# 182272         32.802                       11.645        24.684
# 133853        124.897                        9.227        74.528
# 270567        277.571                       67.423       208.798
# 111578        121.775                       50.411        83.355
# 180451          0.000                       92.255        78.663
#
#          DER_deltar_tau_lep  DER_pt_tot  DER_met_phi_centrality  PRI_tau_pt  \
# EventId
# 182272                0.659       0.580                   0.142      22.464
# 133853                0.568      21.010                   1.413     127.603
# 270567                4.835      29.089                  -1.405      25.848
# 111578                3.208       4.610                  -1.402      30.589
# 180451                2.200       3.861                  -1.414      25.043
#
#          PRI_tau_eta  PRI_tau_phi  PRI_lep_eta  PRI_lep_phi  PRI_met  \
# EventId
# 182272         1.137        0.673        1.699        0.329    1.701
# 133853        -0.633       -0.750       -1.190       -0.859  197.476
# 270567         1.662       -0.690       -2.236        2.170   39.903
# 111578        -1.777        0.912       -0.592       -2.069   16.370
# 180451        -2.192        3.027       -0.111       -2.542   58.864
#
#          PRI_met_phi  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# EventId
# 182272         1.546                1.607               -2.695
# 133853        -0.802               -1.854                2.279
# 270567        -1.723                0.000                0.000
# 111578         1.531                0.000                0.000
# 180451         0.250                0.000                0.000
#
#          PRI_jet_subleading_eta  PRI_jet_subleading_phi    Weight Label
# EventId
# 182272                    0.000                   0.000  2.307501     b
# 133853                   -1.379                   2.361  0.002653     s
# 270567                    0.000                   0.000  6.514393     b
# 111578                    0.000                   0.000  0.018636     s
# 180451                    0.000                   0.000  1.274112     b

# %%
from ydata_profiling import ProfileReport
pr = ProfileReport(df, title="Data Profiling Report", explorative=True)

# %%
pr.to_file('report.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from IPython.display import IFrame
IFrame('report.html', width='100%', height=800)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="report.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# encoding our target feature "Label"
df['Label'] = df['Label'].replace({"b":0, "s":1})

# %%
x = df.drop(columns='Label', axis=1)
y = df['Label']

# %%
y.value_counts()
# Out:
# Label
# 0    164333
# 1     85667
# Name: count, dtype: int64

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                              DER_mass_transverse_met_lep  DER_mass_vis  \
# DER_mass_transverse_met_lep                     1.000000      0.190109
# DER_mass_vis                                    0.190109      1.000000
# DER_pt_h                                       -0.249116     -0.062562
# DER_deltaeta_jet_jet                           -0.181773     -0.038794
# DER_mass_jet_jet                               -0.166375     -0.044463
# DER_prodeta_jet_jet                             0.100320      0.024383
# DER_deltar_tau_lep                              0.043251      0.579712
# DER_pt_tot                                      0.017758     -0.000702
# DER_sum_pt                                     -0.146837      0.088685
# DER_pt_ratio_lep_tau                            0.349504      0.097490
# DER_met_phi_centrality                         -0.419757     -0.090846
# DER_lep_eta_centrality                         -0.165878     -0.044084
# PRI_tau_pt                                     -0.145464      0.290011
# PRI_tau_eta                                    -0.002109      0.002127
# PRI_tau_phi                                     0.001132     -0.003624
# PRI_lep_pt                                      0.310648      0.405482
# PRI_lep_eta                                    -0.006777      0.002196
# PRI_lep_phi                                     0.000340     -0.002018
# PRI_met                                         0.183716     -0.087330
# PRI_met_phi                                    -0.015925     -0.001467
# PRI_met_sumet                                  -0.167811      0.053300
# PRI_jet_leading_pt                             -0.232282     -0.055404
# PRI_jet_leading_eta                             0.000313      0.002092
# PRI_jet_leading_phi                             0.006341      0.004570
# PRI_jet_subleading_pt                          -0.158187     -0.042269
# PRI_jet_subleading_eta                          0.001859      0.001390
# PRI_jet_subleading_phi                          0.003925     -0.000365
# PRI_jet_all_pt                                 -0.210009     -0.052902
# Weight                                          0.419843      0.102172
# has_leading_jet                                -0.220371     -0.013755
# has_subleading_jet                             -0.176234     -0.032206
# mmc_failed                                           NaN           NaN
#
#                              DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# DER_mass_transverse_met_lep -0.249116             -0.181773         -0.166375
# DER_mass_vis                -0.062562             -0.038794         -0.044463
# DER_pt_h                     1.000000              0.381244          0.418997
# DER_deltaeta_jet_jet         0.381244              1.000000          0.877412
# DER_mass_jet_jet             0.418997              0.877412          1.000000
# DER_prodeta_jet_jet         -0.115809             -0.679020         -0.706110
# DER_deltar_tau_lep          -0.539379             -0.215942         -0.235595
# DER_pt_tot                   0.310501              0.135947          0.147097
# DER_sum_pt                   0.832733              0.468517          0.524927
# DER_pt_ratio_lep_tau         0.089187             -0.007276         -0.002108
# DER_met_phi_centrality       0.539356              0.310049          0.279774
# DER_lep_eta_centrality       0.371476              0.829135          0.700068
# PRI_tau_pt                   0.407421              0.150769          0.179802
# PRI_tau_eta                  0.001665              0.002136          0.000550
# PRI_tau_phi                  0.005248              0.001392          0.002518
# PRI_lep_pt                   0.360939              0.090634          0.116189
# PRI_lep_eta                  0.008354              0.004418          0.003903
# PRI_lep_phi                 -0.002923              0.000085         -0.001554
# PRI_met                      0.679585              0.203978          0.260302
# PRI_met_phi                  0.008585              0.002888          0.003741
# PRI_met_sumet                0.782547              0.414847          0.459241
# PRI_jet_leading_pt           0.874578              0.409010          0.476640
# PRI_jet_leading_eta          0.001642             -0.002274         -0.001522
# PRI_jet_leading_phi         -0.001638             -0.001098         -0.000059
# PRI_jet_subleading_pt        0.564091              0.600725          0.618473
# PRI_jet_subleading_eta      -0.002449             -0.006881         -0.005442
# PRI_jet_subleading_phi      -0.005389              0.000248         -0.002171
# PRI_jet_all_pt               0.808616              0.498200          0.552400
# Weight                      -0.414084             -0.340268         -0.293521
# has_leading_jet              0.564894              0.395407          0.322777
# has_subleading_jet           0.523715              0.758015          0.618745
# mmc_failed                        NaN                   NaN               NaN
#
#                              DER_prodeta_jet_jet  DER_deltar_tau_lep  \
# DER_mass_transverse_met_lep             0.100320            0.043251
# DER_mass_vis                            0.024383            0.579712
# DER_pt_h                               -0.115809           -0.539379
# DER_deltaeta_jet_jet                   -0.679020           -0.215942
# DER_mass_jet_jet                       -0.706110           -0.235595
# DER_prodeta_jet_jet                     1.000000            0.062400
# DER_deltar_tau_lep                      0.062400            1.000000
# DER_pt_tot                              0.026580           -0.148081
# DER_sum_pt                             -0.118969           -0.432603
# DER_pt_ratio_lep_tau                    0.034612            0.047046
# DER_met_phi_centrality                 -0.119341           -0.205441
# DER_lep_eta_centrality                 -0.527090           -0.214810
# PRI_tau_pt                             -0.064008           -0.202035
# PRI_tau_eta                             0.001215            0.003632
# PRI_tau_phi                             0.000136           -0.011229
# PRI_lep_pt                             -0.005085           -0.069957
# PRI_lep_eta                             0.000175            0.000699
# PRI_lep_phi                             0.000111           -0.000776
# PRI_met                                -0.050828           -0.402345
# PRI_met_phi                             0.000422           -0.001570
# PRI_met_sumet                          -0.089831           -0.407002
# PRI_jet_leading_pt                     -0.121621           -0.480736
# PRI_jet_leading_eta                    -0.002021            0.000232
# PRI_jet_leading_phi                    -0.001887            0.006562
# PRI_jet_subleading_pt                  -0.156850           -0.318731
# PRI_jet_subleading_eta                 -0.001551            0.002510
# PRI_jet_subleading_phi                  0.002233            0.004132
# PRI_jet_all_pt                         -0.124660           -0.448737
# Weight                                  0.130087            0.197881
# has_leading_jet                        -0.098926           -0.304162
# has_subleading_jet                     -0.189636           -0.299110
# mmc_failed                                   NaN                 NaN
#
#                              DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# DER_mass_transverse_met_lep    0.017758   -0.146837              0.349504
# DER_mass_vis                  -0.000702    0.088685              0.097490
# DER_pt_h                       0.310501    0.832733              0.089187
# DER_deltaeta_jet_jet           0.135947    0.468517             -0.007276
# DER_mass_jet_jet               0.147097    0.524927             -0.002108
# DER_prodeta_jet_jet            0.026580   -0.118969              0.034612
# DER_deltar_tau_lep            -0.148081   -0.432603              0.047046
# DER_pt_tot                     1.000000    0.381160              0.039193
# DER_sum_pt                     0.381160    1.000000              0.108791
# DER_pt_ratio_lep_tau           0.039193    0.108791              1.000000
# DER_met_phi_centrality         0.178448    0.420679             -0.038803
# DER_lep_eta_centrality         0.125701    0.451309             -0.000122
# PRI_tau_pt                     0.095754    0.485847             -0.474633
# PRI_tau_eta                    0.003596    0.002037              0.000611
# PRI_tau_phi                    0.001452    0.003931              0.000004
# PRI_lep_pt                     0.109617    0.460938              0.701142
# PRI_lep_eta                    0.007987    0.008781              0.002357
# PRI_lep_phi                   -0.004249   -0.001892             -0.005053
# PRI_met                        0.269739    0.520129              0.053386
# PRI_met_phi                    0.002515    0.006712             -0.001186
# PRI_met_sumet                  0.448925    0.904481              0.049904
# PRI_jet_leading_pt             0.268569    0.913640              0.079182
# PRI_jet_leading_eta           -0.005526    0.000109              0.002851
# PRI_jet_leading_phi            0.002838    0.000029             -0.000668
# PRI_jet_subleading_pt          0.353211    0.802925              0.052180
# PRI_jet_subleading_eta        -0.000806   -0.003600              0.001815
# PRI_jet_subleading_phi        -0.003661   -0.005825              0.002870
# PRI_jet_all_pt                 0.403382    0.965628              0.079116
# Weight                        -0.219507   -0.414827              0.188398
# has_leading_jet                0.186580    0.578616              0.043315
# has_subleading_jet             0.271099    0.672127              0.041430
# mmc_failed                          NaN         NaN                   NaN
#
#                              ...  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# DER_mass_transverse_met_lep  ...             0.000313             0.006341
# DER_mass_vis                 ...             0.002092             0.004570
# DER_pt_h                     ...             0.001642            -0.001638
# DER_deltaeta_jet_jet         ...            -0.002274            -0.001098
# DER_mass_jet_jet             ...            -0.001522            -0.000059
# DER_prodeta_jet_jet          ...            -0.002021            -0.001887
# DER_deltar_tau_lep           ...             0.000232             0.006562
# DER_pt_tot                   ...            -0.005526             0.002838
# DER_sum_pt                   ...             0.000109             0.000029
# DER_pt_ratio_lep_tau         ...             0.002851            -0.000668
# DER_met_phi_centrality       ...             0.002996            -0.002305
# DER_lep_eta_centrality       ...            -0.000988            -0.000750
# PRI_tau_pt                   ...             0.000317             0.002958
# PRI_tau_eta                  ...             0.163124            -0.000899
# PRI_tau_phi                  ...             0.001642            -0.143726
# PRI_lep_pt                   ...             0.002827             0.000976
# PRI_lep_eta                  ...             0.177768             0.000029
# PRI_lep_phi                  ...             0.003044            -0.222633
# PRI_met                      ...            -0.001204             0.002100
# PRI_met_phi                  ...             0.002005            -0.225064
# PRI_met_sumet                ...            -0.000638             0.001768
# PRI_jet_leading_pt           ...             0.000372            -0.001997
# PRI_jet_leading_eta          ...             1.000000            -0.005987
# PRI_jet_leading_phi          ...            -0.005987             1.000000
# PRI_jet_subleading_pt        ...            -0.000881             0.000459
# PRI_jet_subleading_eta       ...            -0.157561             0.001742
# PRI_jet_subleading_phi       ...             0.000598            -0.041338
# PRI_jet_all_pt               ...            -0.000580            -0.000862
# Weight                       ...             0.000981             0.003477
# has_leading_jet              ...            -0.001160            -0.004320
# has_subleading_jet           ...            -0.001828            -0.000960
# mmc_failed                   ...                  NaN                  NaN
#
#                              PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# DER_mass_transverse_met_lep              -0.158187                0.001859
# DER_mass_vis                             -0.042269                0.001390
# DER_pt_h                                  0.564091               -0.002449
# DER_deltaeta_jet_jet                      0.600725               -0.006881
# DER_mass_jet_jet                          0.618473               -0.005442
# DER_prodeta_jet_jet                      -0.156850               -0.001551
# DER_deltar_tau_lep                       -0.318731                0.002510
# DER_pt_tot                                0.353211               -0.000806
# DER_sum_pt                                0.802925               -0.003600
# DER_pt_ratio_lep_tau                      0.052180                0.001815
# DER_met_phi_centrality                    0.329699               -0.003539
# DER_lep_eta_centrality                    0.570265               -0.002390
# PRI_tau_pt                                0.214297               -0.001428
# PRI_tau_eta                               0.002987                0.080468
# PRI_tau_phi                               0.003967                0.001234
# PRI_lep_pt                                0.197807                0.000124
# PRI_lep_eta                               0.006798                0.083798
# PRI_lep_phi                              -0.001050               -0.003135
# PRI_met                                   0.368491                0.001161
# PRI_met_phi                               0.005387               -0.004371
# PRI_met_sumet                             0.735280               -0.003078
# PRI_jet_leading_pt                        0.650489               -0.003302
# PRI_jet_leading_eta                      -0.000881               -0.157561
# PRI_jet_leading_phi                       0.000459                0.001742
# PRI_jet_subleading_pt                     1.000000               -0.003791
# PRI_jet_subleading_eta                   -0.003791                1.000000
# PRI_jet_subleading_phi                   -0.007921                0.003384
# PRI_jet_all_pt                            0.854311               -0.003951
# Weight                                   -0.344183                0.002252
# has_leading_jet                           0.435746               -0.002562
# has_subleading_jet                        0.835301               -0.004912
# mmc_failed                                     NaN                     NaN
#
#                              PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  \
# DER_mass_transverse_met_lep                0.003925       -0.210009  0.419843
# DER_mass_vis                              -0.000365       -0.052902  0.102172
# DER_pt_h                                  -0.005389        0.808616 -0.414084
# DER_deltaeta_jet_jet                       0.000248        0.498200 -0.340268
# DER_mass_jet_jet                          -0.002171        0.552400 -0.293521
# DER_prodeta_jet_jet                        0.002233       -0.124660  0.130087
# DER_deltar_tau_lep                         0.004132       -0.448737  0.197881
# DER_pt_tot                                -0.003661        0.403382 -0.219507
# DER_sum_pt                                -0.005825        0.965628 -0.414827
# DER_pt_ratio_lep_tau                       0.002870        0.079116  0.188398
# DER_met_phi_centrality                    -0.006332        0.452224 -0.472163
# DER_lep_eta_centrality                    -0.001420        0.476155 -0.314403
# PRI_tau_pt                                -0.005132        0.321341 -0.284649
# PRI_tau_eta                                0.000896        0.003763 -0.005647
# PRI_tau_phi                               -0.055468        0.004844  0.003224
# PRI_lep_pt                                 0.000368        0.295108 -0.020769
# PRI_lep_eta                                0.002051        0.010278 -0.019407
# PRI_lep_phi                               -0.075504       -0.002270 -0.002239
# PRI_met                                   -0.001998        0.535217 -0.116031
# PRI_met_phi                               -0.069367        0.007076 -0.009315
# PRI_met_sumet                             -0.004599        0.884413 -0.427235
# PRI_jet_leading_pt                        -0.003078        0.925194 -0.426953
# PRI_jet_leading_eta                        0.000598       -0.000580  0.000981
# PRI_jet_leading_phi                       -0.041338       -0.000862  0.003477
# PRI_jet_subleading_pt                     -0.007921        0.854311 -0.344183
# PRI_jet_subleading_eta                     0.003384       -0.003951  0.002252
# PRI_jet_subleading_phi                     1.000000       -0.005786  0.001505
# PRI_jet_all_pt                            -0.005786        1.000000 -0.419934
# Weight                                     0.001505       -0.419934  1.000000
# has_leading_jet                           -0.000383        0.608208 -0.502733
# has_subleading_jet                        -0.000734        0.712581 -0.395247
# mmc_failed                                      NaN             NaN       NaN
#
#                              has_leading_jet  has_subleading_jet  mmc_failed
# DER_mass_transverse_met_lep        -0.220371           -0.176234         NaN
# DER_mass_vis                       -0.013755           -0.032206         NaN
# DER_pt_h                            0.564894            0.523715         NaN
# DER_deltaeta_jet_jet                0.395407            0.758015         NaN
# DER_mass_jet_jet                    0.322777            0.618745         NaN
# DER_prodeta_jet_jet                -0.098926           -0.189636         NaN
# DER_deltar_tau_lep                 -0.304162           -0.299110         NaN
# DER_pt_tot                          0.186580            0.271099         NaN
# DER_sum_pt                          0.578616            0.672127         NaN
# DER_pt_ratio_lep_tau                0.043315            0.041430         NaN
# DER_met_phi_centrality              0.534401            0.368395         NaN
# DER_lep_eta_centrality              0.362920            0.695698         NaN
# PRI_tau_pt                          0.170909            0.188061         NaN
# PRI_tau_eta                         0.009331            0.004871         NaN
# PRI_tau_phi                         0.003362            0.003305         NaN
# PRI_lep_pt                          0.158853            0.168156         NaN
# PRI_lep_eta                         0.021158            0.008684         NaN
# PRI_lep_phi                         0.000535            0.000069         NaN
# PRI_met                             0.252512            0.305649         NaN
# PRI_met_phi                         0.006449            0.005248         NaN
# PRI_met_sumet                       0.541379            0.619274         NaN
# PRI_jet_leading_pt                  0.662299            0.561316         NaN
# PRI_jet_leading_eta                -0.001160           -0.001828         NaN
# PRI_jet_leading_phi                -0.004320           -0.000960         NaN
# PRI_jet_subleading_pt               0.435746            0.835301         NaN
# PRI_jet_subleading_eta             -0.002562           -0.004912         NaN
# PRI_jet_subleading_phi             -0.000383           -0.000734         NaN
# PRI_jet_all_pt                      0.608208            0.712581         NaN
# Weight                             -0.502733           -0.395247         NaN
# has_leading_jet                     1.000000            0.521664         NaN
# has_subleading_jet                  0.521664            1.000000         NaN
# mmc_failed                               NaN                 NaN         NaN
#
# [32 rows x 32 columns]

# %%
# since 'Weight' column is highly correlated in our data, we can't use this as a feature.

# %%
print(df.shape)

numerical_cols = df.select_dtypes(include=np.number).columns

plt.figure(figsize=(15, 20))
for i, col in enumerate(numerical_cols):
    plt.subplot(8, 4, i + 1)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()
# Out:
# (250000, 33)

# %%
sns.countplot(x=df['Label'], fill=True,legend=True,)
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %%
df['Label'].value_counts()/len(df)*100
# Out:
# Label
# b    65.7332
# s    34.2668
# Name: count, dtype: float64

# %%
df.shape
# Out:
# (250000, 33)

# %%
x = df.drop(columns=['Label','Weight'])
y = df['Label']
sample_weight = df['Weight']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest, ytrain, ytest, wtrain, wtest = train_test_split(x, y, sample_weight, test_size=0.20, random_state=45, stratify=y)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ytrain_enc = le.fit_transform(ytrain)
ytest_enc = le.transform(ytest)

# %%
# from imblearn.over_sampling import SMOTE
# smote = SMOTE(random_state=42)
# xtrain_res, ytrain_res = smote.fit_resample(xtrain, ytrain_enc)

# %%
sns.countplot(x=ytrain_enc, fill=True,legend=True)
# Out:
# <Axes: ylabel='count'>

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(xtrain, ytrain_enc, sample_weight=wtrain)
# Out:
# LogisticRegression()

# %%
ypred = lr.predict(xtest)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest_enc, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.79     32867
#            1       1.00      0.00      0.01     17133
#
#     accuracy                           0.66     50000
#    macro avg       0.83      0.50      0.40     50000
# weighted avg       0.78      0.66      0.52     50000

# %%
from sklearn.ensemble import AdaBoostClassifier
adb = AdaBoostClassifier()
adb.fit(xtrain, ytrain_enc)
# Out:
# AdaBoostClassifier()

# %%
ypred = adb.predict(xtest)
print(classification_report(ypred, ytest_enc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85     34380
#            1       0.66      0.72      0.69     15620
#
#     accuracy                           0.80     50000
#    macro avg       0.76      0.78      0.77     50000
# weighted avg       0.80      0.80      0.80     50000

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(xtrain, ytrain_enc)

y_pred = dt_model.predict(xtest)
print(classification_report(ytest_enc, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81     32867
#            1       0.64      0.65      0.65     17133
#
#     accuracy                           0.76     50000
#    macro avg       0.73      0.73      0.73     50000
# weighted avg       0.76      0.76      0.76     50000

# %%
feature_importances = dt_model.feature_importances_

feature_importance_df = pd.DataFrame({
    'Feature': x.columns,
    'Importance': feature_importances
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print("Feature Importances (Decision Tree):")
display(feature_importance_df)
# Out:
# Feature Importances (Decision Tree):
#                         Feature  Importance
# 0   DER_mass_transverse_met_lep    0.182989
# 1                  DER_mass_vis    0.168797
# 18                      PRI_met    0.069218
# 12                   PRI_tau_pt    0.062690
# 10       DER_met_phi_centrality    0.053528
# 6            DER_deltar_tau_lep    0.052265
# 7                    DER_pt_tot    0.031325
# 16                  PRI_lep_eta    0.029624
# 20                PRI_met_sumet    0.027925
# 14                  PRI_tau_phi    0.027646
# 13                  PRI_tau_eta    0.026267
# 17                  PRI_lep_phi    0.025709
# 2                      DER_pt_h    0.025359
# 22          PRI_jet_leading_eta    0.024719
# 19                  PRI_met_phi    0.024336
# 3          DER_deltaeta_jet_jet    0.022936
# 15                   PRI_lep_pt    0.022748
# 8                    DER_sum_pt    0.020572
# 9          DER_pt_ratio_lep_tau    0.019539
# 23          PRI_jet_leading_phi    0.017929
# 11       DER_lep_eta_centrality    0.010631
# 21           PRI_jet_leading_pt    0.010217
# 27               PRI_jet_all_pt    0.009326
# 4              DER_mass_jet_jet    0.008533
# 26       PRI_jet_subleading_phi    0.007232
# 5           DER_prodeta_jet_jet    0.006673
# 25       PRI_jet_subleading_eta    0.006283
# 24        PRI_jet_subleading_pt    0.004471
# 29           has_subleading_jet    0.000292
# 28              has_leading_jet    0.000223
# 30                   mmc_failed    0.000000

# %%
# trying keeping missing values
df2.sample(4)
# Out:
#          DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# EventId
# 291956        140.882                        9.619        93.852     1.540
# 344986        109.176                       63.982       100.570     5.982
# 163451         69.377                       23.715        43.997   105.402
# 122283         45.206                       56.515        38.485    11.370
#
#          DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# EventId
# 291956                  0.000             0.000                0.000
# 344986                  0.000             0.000                0.000
# 163451                  2.446           245.934               -0.588
# 122283                  0.000             0.000                0.000
#
#          DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_jet_num  \
# EventId                                              ...
# 291956                3.367       1.540      72.279  ...            0
# 344986                2.381       5.982     103.614  ...            0
# 163451                1.240      43.424     339.426  ...            3
# 122283                1.615      11.370      52.946  ...            0
#
#          PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# EventId
# 291956                0.000                 0.00                0.000
# 344986                0.000                 0.00                0.000
# 163451               98.499                 0.27               -0.065
# 122283                0.000                 0.00                0.000
#
#          PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# EventId
# 291956                   0.000                   0.000
# 344986                   0.000                   0.000
# 163451                  51.979                  -2.176
# 122283                   0.000                   0.000
#
#          PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  Label
# EventId
# 291956                    0.000           0.000  0.018636      s
# 344986                    0.000           0.000  4.244525      b
# 163451                   -1.624         264.435  0.307170      b
# 122283                    0.000           0.000  4.595855      b
#
# [4 rows x 32 columns]

# %%
from sklearn.model_selection import train_test_split
x = df2.drop(columns=['Label','Weight'])
y = df2['Label']
sweight = df2['Weight']
xtrain, xtest, ytrain, ytest, wtrain, wtest = train_test_split(x,y,sweight, test_size=0.20, random_state=312)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ytrain_e = le.fit_transform(ytrain)
ytest_e = le.transform(ytest)

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    n_estimators=500,
    learning_rate = 0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

# %%
xgb.fit(xtrain,ytrain_e, sample_weight=wtrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
ypred = xgb.predict_proba(xtest)[:,1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(ytest_e, ypred, sample_weight=wtest)
print("Wighted AUC:", auc)
ypred = xgb.predict(xtest)
from sklearn.metrics import classification_report
print(classification_report(ytest_e, ypred, sample_weight=wtest))
# Out:
# Wighted AUC: 0.9343270315556134
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00 82035.17077578
#            1       0.28      0.02      0.05 138.6257973739784
#
#     accuracy                           1.00 82173.79657315399
#    macro avg       0.64      0.51      0.52 82173.79657315399
# weighted avg       1.00      1.00      1.00 82173.79657315399
